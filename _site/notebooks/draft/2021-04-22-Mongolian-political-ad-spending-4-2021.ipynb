# %% [markdown]
# # Mongolia's Political Ad Spending April 2021

# %% [markdown]
# This is a monthly template for making the political ad spending report for Mongolia. The following visualization/analyses will be performed:
#
# 1. Number of ads by day
#     - Use days active to determine this
# 2. Top Facebook pages by ad spending
# 3. Total amount spent during this time (show a range)
# 4. Show ads with most impressions - top 5
# 5. LDA analysis for top 3 topics

# %%
import pandas as pd
import numpy as np
import psycopg2
import ast
import datetime

from config import conn_str
conn_str = conn_str('facebook')

# %%
conn = psycopg2.connect(conn_str)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
start_date = datetime.datetime(year=2021, month=4, day=1)
end_date = datetime.datetime(year=2021, month=4, day=30)

# %% [markdown]
# ## Import Tables

# %% [markdown]
# There are two tables:
# - fb_ad_lib_ad_data
# - fb_ad_lib_pages

# %%
ads = pd.read_sql('select * from fb_ad_lib_ad_data;', conn)
pages = pd.read_sql('select * from fb_ad_lib_pages;', conn)

# %%
ads.shape
# Out:
# (5555, 19)

# %%
pages.shape
# Out:
# (1443, 5)

# %%
ads.head()
# Out:
#   ad_creation_time                                   ad_creative_body  \
# 0       2021-04-30  Монгол улсын ерөнхийлөгчид Ардчилсан намаас нэ...
# 1       2021-04-29  САНАЛ ӨГӨХ ЗААВАР:🇲🇳nАрдчилсан нам Монгол улса...
# 2       2021-04-29  🇲🇳Монгол улсын #Ерөнxийлөгчид Ардчилсан намаас...
# 3       2021-04-29  🇲🇳Монгол улсын #Ерөнxийлөгчид Ардчилсан намаас...
# 4       2021-04-29  АРДЧИЛСАН НАМЫН ЭЭЛЖИТ XII ЦАХИМ ИХ ХУРАЛ 2021...
#
#                               ad_creative_link_title ad_delivery_start_time  \
# 0  Монгол улсын ерөнхийлөгчид Ардчилсан намаас нэ...             2021-04-30
# 1                                                nan             2021-04-30
# 2                                                nan             2021-04-30
# 3                                                nan             2021-04-29
# 4                                                nan             2021-04-29
#
#   ad_delivery_stop_time                                    ad_snapshot_url  \
# 0            2021-05-02  https://www.facebook.com/ads/archive/render_ad...
# 1            2021-05-02  https://www.facebook.com/ads/archive/render_ad...
# 2            2021-05-01  https://www.facebook.com/ads/archive/render_ad...
# 3            2021-05-02  https://www.facebook.com/ads/archive/render_ad...
# 4            2021-05-03  https://www.facebook.com/ads/archive/render_ad...
#
#   currency                           demographic_distribution  \
# 0      USD  [{'percentage': '0.046576', 'age': '55-64', 'g...
# 1      USD  [{'percentage': '0.000132', 'age': '25-34', 'g...
# 2      USD  [{'percentage': '6.1E-5', 'age': '55-64', 'gen...
# 3      USD  [{'percentage': '1.0E-5', 'age': '65+', 'gende...
# 4      USD  [{'percentage': '3.6E-5', 'age': '18-24', 'gen...
#
#         funding_entity               id  \
# 0  Enkhmurun Erdenebat  808086169839504
# 1  Enkhmurun Erdenebat  811746283053829
# 2  Enkhmurun Erdenebat  537189683968489
# 3  Enkhmurun Erdenebat  246035923936971
# 4  Enkhmurun Erdenebat  170373828293644
#
#                                          impressions          page_id  \
# 0   {'lower_bound': '30000', 'upper_bound': '34999'}  100179472105159
# 1   {'lower_bound': '25000', 'upper_bound': '29999'}  100179472105159
# 2   {'lower_bound': '20000', 'upper_bound': '24999'}  100179472105159
# 3  {'lower_bound': '350000', 'upper_bound': '3999...  100179472105159
# 4   {'lower_bound': '90000', 'upper_bound': '99999'}  100179472105159
#
#                         page_name             potential_reach  \
# 0  Democratic Party Ардчилсан нам  {'lower_bound': '1000001'}
# 1  Democratic Party Ардчилсан нам  {'lower_bound': '1000001'}
# 2  Democratic Party Ардчилсан нам  {'lower_bound': '1000001'}
# 3  Democratic Party Ардчилсан нам  {'lower_bound': '1000001'}
# 4  Democratic Party Ардчилсан нам  {'lower_bound': '1000001'}
#
#          publisher_platforms  \
# 0               ['facebook']
# 1  ['facebook', 'instagram']
# 2  ['facebook', 'instagram']
# 3  ['facebook', 'instagram']
# 4  ['facebook', 'instagram']
#
#                                  region_distribution  \
# 0  [{'percentage': '0.014488', 'region': 'Övörkha...
# 1  [{'percentage': '0.012833', 'region': 'Arkhang...
# 2  [{'percentage': '0.010928', 'region': 'Arkhang...
# 3  [{'percentage': '0.011469', 'region': 'Arkhang...
# 4      [{'percentage': '1', 'region': 'Ulan Bator'}]
#
#                                           spend ad_creative_link_caption  \
# 0     {'lower_bound': '0', 'upper_bound': '99'}                      nan
# 1     {'lower_bound': '0', 'upper_bound': '99'}                      nan
# 2     {'lower_bound': '0', 'upper_bound': '99'}                      nan
# 3  {'lower_bound': '100', 'upper_bound': '199'}                      nan
# 4  {'lower_bound': '100', 'upper_bound': '199'}                      nan
#
#   ad_creative_link_description
# 0                          nan
# 1                          nan
# 2                          nan
# 3                          nan
# 4                          nan

# %%
pages.head()
# Out:
#             Page ID                       Page Name             Disclaimer  \
# 0   100179472105159  Democratic Party Ардчилсан нам    Enkhmurun Erdenebat
# 1   844579789004530              Хассуурийн Ганхуяг    Khassuuri Gankhuyag
# 2   108721589821589            Ганибалын Амартүвшин      Nurbyek Samalkhan
# 3  1204136139605142    Болдын Жавхлан Javkhlan Bold  Enkhtungalag Nyamdorj
# 4  1645028429160586                   Дамбын Батлут       Энхчулуун Чинбат
#
#   Amount Spent (USD) Number of Ads in Library
# 0               1710                       32
# 1               1530                       45
# 2                472                       36
# 3                458                        7
# 4                415                       14

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Date Filter

# %% [markdown]
# Our time period of interest is April 2021. Filter the ads dataframe on that.

# %%
ads['ad_delivery_start_time'] = pd.to_datetime(ads['ad_delivery_start_time'])
ads['ad_delivery_stop_time'] = pd.to_datetime(ads['ad_delivery_stop_time'])
ads['ad_creation_time'] = pd.to_datetime(ads['ad_creation_time'])

# %%
ads = ads[(ads['ad_delivery_start_time'] >= start_date) & (ads['ad_delivery_start_time'] <= end_date)]

# %% [markdown]
# ### Eliminate Duplicates

# %% [markdown]
# The Facebook API has duplicate pages that have the same Page ID but different numbers of ads. It seem the pages farther up the list are the newer/correct ones, so we will keep those and drop the duplicates.

# %%
pages[pages.duplicated(subset=['Page ID'], keep=False)].sort_values('Page Name').head()
# Out:
#               Page ID                          Page Name  \
# 500   125084321493311                 Altansor Tsogtkhuu
# 90    125084321493311                 Altansor Tsogtkhuu
# 621   125084321493311                 Altansor Tsogtkhuu
# 437  1118243471545672  Baatar Jamsran Жамсрангийн Баатар
# 242  1118243471545672  Baatar Jamsran Жамсрангийн Баатар
#
#                              Disclaimer Amount Spent (USD)  \
# 500                     Munkhtur Ravjir               ≤100
# 90                       Altansor Soroo                385
# 621  These ads ran without a disclaimer               ≤100
# 437                       Tamir Odgerel               ≤100
# 242                Sodmagnai Enkhjargal               ≤100
#
#     Number of Ads in Library
# 500                        1
# 90                        10
# 621                        1
# 437                        3
# 242                        2

# %%
pages = pages.drop_duplicates(subset=['Page ID'], keep='first')

# %%
pages.head()
# Out:
#             Page ID                       Page Name             Disclaimer  \
# 0   100179472105159  Democratic Party Ардчилсан нам    Enkhmurun Erdenebat
# 1   844579789004530              Хассуурийн Ганхуяг    Khassuuri Gankhuyag
# 2   108721589821589            Ганибалын Амартүвшин      Nurbyek Samalkhan
# 3  1204136139605142    Болдын Жавхлан Javkhlan Bold  Enkhtungalag Nyamdorj
# 4  1645028429160586                   Дамбын Батлут       Энхчулуун Чинбат
#
#   Amount Spent (USD) Number of Ads in Library
# 0               1710                       32
# 1               1530                       45
# 2                472                       36
# 3                458                        7
# 4                415                       14

# %% [markdown]
# For page spend we will list everything '<=100' to 100 for proper plotting.

# %%
pages['Amount Spent (USD)'] = pages['Amount Spent (USD)'].replace(to_replace='≤100', value='100').astype('int')

# %% [markdown]
# Now that we have removed the duplicates we can merge the dataframes.

# %%
df = ads.merge(pages, how='left', left_on='page_id', right_on='Page ID')

# %%
df = df.drop(columns=['Amount Spent (USD)','Number of Ads in Library'])

# %%
df.sample(2)
# Out:
#     ad_creation_time                                   ad_creative_body  \
# 207       2021-04-18  🏙 Энэ хөл хориотой үед Сөүл Гарден цогцолборын...
# 27        2021-04-15  Засгийн Газрын хэрэгжүүлэгч агентлаг Гэр бүл, ...
#
#     ad_creative_link_title ad_delivery_start_time ad_delivery_stop_time  \
# 207                    nan             2021-04-18            2021-04-19
# 27                     nan             2021-04-15            2021-04-17
#
#                                        ad_snapshot_url currency  \
# 207  https://www.facebook.com/ads/archive/render_ad...      USD
# 27   https://www.facebook.com/ads/archive/render_ad...      USD
#
#                               demographic_distribution     funding_entity  \
# 207  [{'percentage': '0.000364', 'age': '35-44', 'g...                nan
# 27   [{'percentage': '0.034195', 'age': '18-24', 'g...  Nurbyek Samalkhan
#
#                    id                                       impressions  \
# 207   299950818168566  {'lower_bound': '10000', 'upper_bound': '14999'}
# 27   1020541158479190    {'lower_bound': '3000', 'upper_bound': '3999'}
#
#              page_id               page_name             potential_reach  \
# 207  577689219250430  Seoul Garden цогцолбор  {'lower_bound': '1000001'}
# 27   108721589821589    Ганибалын Амартүвшин  {'lower_bound': '1000001'}
#
#            publisher_platforms                            region_distribution  \
# 207  ['facebook', 'instagram']  [{'percentage': '1', 'region': 'Ulan Bator'}]
# 27                ['facebook']  [{'percentage': '1', 'region': 'Ulan Bator'}]
#
#                                          spend ad_creative_link_caption  \
# 207  {'lower_bound': '0', 'upper_bound': '99'}                      nan
# 27   {'lower_bound': '0', 'upper_bound': '99'}                      nan
#
#     ad_creative_link_description          Page ID               Page Name  \
# 207                          nan  577689219250430  Seoul Garden цогцолбор
# 27                           nan  108721589821589    Ганибалын Амартүвшин
#
#                              Disclaimer
# 207  These ads ran without a disclaimer
# 27                    Nurbyek Samalkhan

# %% [markdown]
# ### Convert nested data to columns

# %% [markdown]
# **Potential Reach**

# %%
df = pd.concat([df.drop(columns='potential_reach'), 
                pd.json_normalize(df['potential_reach'].map(eval))], axis=1)

# %%
df = df.rename(columns={'lower_bound':'reach_lower', 'upper_bound':'reach_upper'})

# %% [markdown]
# **Spend**

# %%
df = pd.concat([df.drop(columns='spend'), 
                pd.json_normalize(df['spend'].map(eval))], axis=1)

# %%
df = df.rename(columns={'lower_bound':'spend_lower', 'upper_bound':'spend_upper'})

# %% [markdown]
# **Impressions**

# %%
df = pd.concat([df.drop(columns='impressions'), 
                pd.json_normalize(df['impressions'].map(eval))], axis=1)

# %%
df = df.rename(columns={'lower_bound':'impressions_lower', 
                        'upper_bound':'impressions_upper'})

# %% [markdown]
# ### Separate Demographics into Columns

# %%
pd.DataFrame(ast.literal_eval(df['demographic_distribution'].iloc[0]))
# Out:
#    percentage    age   gender
# 0    0.046576  55-64     male
# 1    0.108474  25-34   female
# 2      4.1E-5  55-64  unknown
# 3    0.019407    65+     male
# 4     0.10974  45-54     male
# 5    0.028681  18-24     male
# 6    0.052296  55-64   female
# 7    0.122732  35-44   female
# 8     0.10018  45-54   female
# 9    0.180667  25-34     male
# 10   0.021858  18-24   female
# 11     4.1E-5  18-24  unknown
# 12   0.016833    65+   female
# 13   0.000204  45-54  unknown
# 14    0.00049  35-44  unknown
# 15   0.000163  25-34  unknown
# 16   0.191535  35-44     male
# 17     8.2E-5    65+  unknown

# %% [markdown]
# ### Filter to only Mongolian ads

# %% [markdown]
# There are often international advertisers that will end up in the political and social issue ad category. These ads are generally in English or Russian. We can filter these ads out by detecting the language of each ad. We will then filter for only Mongolian.

# %%
def translate_text(target, text):
    """Translates text into the target language.

    Target must be an ISO 639-1 language code.
    See https://g.co/cloud/translate/v2/translate-reference#supported_languages
    """
    import six
    from google.cloud import translate_v2 as translate

    translate_client = translate.Client()

    if isinstance(text, six.binary_type):
        text = text.decode("utf-8")

    # Text can also be a sequence of strings, in which case this method
    # will return a sequence of results for each text.
    result = translate_client.translate(text, target_language=target)

    print(u"Text: {}".format(result["input"]))
    print(u"Translation: {}".format(result["translatedText"]))
    print(u"Detected source language: {}".format(result["detectedSourceLanguage"]))

# %%
df['ad_creative_body'][0]
# Out:
# 'Монгол улсын ерөнхийлөгчид Ардчилсан намаас нэр дэвшигчдийн бодлогын мэтгэлцээн'

# %%
translate_text('en', df['ad_creative_body'][0])
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# <ipython-input-29-86a2c82dfc39> in <module>
# ----> 1 translate_text('en', df['ad_creative_body'][0])
#
# <ipython-input-26-6c9e725cde92> in translate_text(target, text)
#       8     from google.cloud import translate_v2 as translate
#       9
# ---> 10     translate_client = translate.Client()
#      11
#      12     if isinstance(text, six.binary_type):
#
# ~/anaconda3/envs/standard/lib/python3.8/site-packages/google/cloud/translate_v2/client.py in __init__(self, target_language, credentials, _http, client_info, client_options)
#      80     ):
#      81         self.target_language = target_language
# ---> 82         super(Client, self).__init__(credentials=credentials, _http=_http)
#      83
#      84         kw_args = {"client_info": client_info}
#
# ~/anaconda3/envs/standard/lib/python3.8/site-packages/google/cloud/client.py in __init__(self, credentials, _http, client_options)
#     151                     client_options.credentials_file, scopes=scopes)
#     152             else:
# --> 153                 credentials, _ = google.auth.default(scopes=scopes)
#     154
#     155         self._credentials = google.auth.credentials.with_scopes_if_required(
#
# ~/anaconda3/envs/standard/lib/python3.8/site-packages/google/auth/_default.py in default(scopes, request, quota_project_id, default_scopes)
#     481             return credentials, effective_project_id
#     482
# --> 483     raise exceptions.DefaultCredentialsError(_HELP_MESSAGE)
#
# DefaultCredentialsError: Could not automatically determine credentials. Please set GOOGLE_APPLICATION_CREDENTIALS or explicitly create credentials and re-run the application. For more information, please see https://cloud.google.com/docs/authentication/getting-started

# %%
df['ad_lang'] = df['ad_creative_body'].apply(lambda x: TextBlob(x).detect_language())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-38-2f3a94c87b31> in <module>
# ----> 1 df['ad_lang'] = df['ad_creative_body'].apply(lambda x: TextBlob(x).detect_language())
#
# ~/anaconda3/envs/standard/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4106             else:
#    4107                 values = self.astype(object)._values
# -> 4108                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4109
#    4110         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-38-2f3a94c87b31> in <lambda>(x)
# ----> 1 df['ad_lang'] = df['ad_creative_body'].apply(lambda x: TextBlob(x).detect_language())
#
# ~/anaconda3/envs/standard/lib/python3.8/site-packages/textblob/blob.py in detect_language(self)
#     566         :rtype: str
#     567         """
# --> 568         return self.translator.detect(self.raw)
#     569
#     570     def correct(self):
#
# ~/anaconda3/envs/standard/lib/python3.8/site-packages/textblob/translate.py in detect(self, source, host, type_)
#      70         data = {"q": source}
#      71         url = u'{url}&sl=auto&tk={tk}'.format(url=self.url, tk=_calculate_tk(source))
# ---> 72         response = self._request(url, host=host, type_=type_, data=data)
#      73         result, language = json.loads(response)
#      74         return language
#
# ~/anaconda3/envs/standard/lib/python3.8/site-packages/textblob/translate.py in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# ~/anaconda3/envs/standard/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/anaconda3/envs/standard/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/anaconda3/envs/standard/lib/python3.8/urllib/request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~/anaconda3/envs/standard/lib/python3.8/urllib/request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~/anaconda3/envs/standard/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~/anaconda3/envs/standard/lib/python3.8/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~/anaconda3/envs/standard/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/anaconda3/envs/standard/lib/python3.8/urllib/request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~/anaconda3/envs/standard/lib/python3.8/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~/anaconda3/envs/standard/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~/anaconda3/envs/standard/lib/python3.8/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests

# %%
df = df[df['ad_lang'] == 'mn']

# %% [markdown]
# ## Top Facebook pages by ad spending

# %% [markdown]
# Calculate the number of days the ad ran. This sets a minimum value for ad spend.

# %%
df['ad_days'] = df['ad_delivery_stop_time'] - df['ad_delivery_start_time']

# %%
df['ad_days'] = df['ad_days'].dt.days

# %% [markdown]
# Convert spend_lower and spend_upper to int so we can do math on it.

# %%
df['spend_lower'] = df['spend_lower'].astype('int')

# %%
df['spend_upper'] = df['spend_upper'].astype('int')

# %% [markdown]
# If the spend_lower value is 0, we can change that to a realistic minimum by taking the number of days as the absolute minimum, as there is a 1 dollar per day minimum.

# %%
df['spend_lower'] = df['spend_lower'].mask(df['spend_lower']==0, df['spend_lower'] + df['ad_days'])

# %%
df.head(2)
# Out:
#   ad_creation_time                                   ad_creative_body  \
# 0       2021-04-30  Монгол улсын ерөнхийлөгчид Ардчилсан намаас нэ...
# 1       2021-04-29  САНАЛ ӨГӨХ ЗААВАР:🇲🇳nАрдчилсан нам Монгол улса...
#
#                               ad_creative_link_title ad_delivery_start_time  \
# 0  Монгол улсын ерөнхийлөгчид Ардчилсан намаас нэ...             2021-04-30
# 1                                                nan             2021-04-30
#
#   ad_delivery_stop_time                                    ad_snapshot_url  \
# 0            2021-05-02  https://www.facebook.com/ads/archive/render_ad...
# 1            2021-05-02  https://www.facebook.com/ads/archive/render_ad...
#
#   currency                           demographic_distribution  \
# 0      USD  [{'percentage': '0.046576', 'age': '55-64', 'g...
# 1      USD  [{'percentage': '0.000132', 'age': '25-34', 'g...
#
#         funding_entity               id  \
# 0  Enkhmurun Erdenebat  808086169839504
# 1  Enkhmurun Erdenebat  811746283053829
#
#                                         impressions          page_id  \
# 0  {'lower_bound': '30000', 'upper_bound': '34999'}  100179472105159
# 1  {'lower_bound': '25000', 'upper_bound': '29999'}  100179472105159
#
#                         page_name        publisher_platforms  \
# 0  Democratic Party Ардчилсан нам               ['facebook']
# 1  Democratic Party Ардчилсан нам  ['facebook', 'instagram']
#
#                                  region_distribution ad_creative_link_caption  \
# 0  [{'percentage': '0.014488', 'region': 'Övörkha...                      nan
# 1  [{'percentage': '0.012833', 'region': 'Arkhang...                      nan
#
#   ad_creative_link_description          Page ID  \
# 0                          nan  100179472105159
# 1                          nan  100179472105159
#
#                         Page Name           Disclaimer reach_lower  \
# 0  Democratic Party Ардчилсан нам  Enkhmurun Erdenebat     1000001
# 1  Democratic Party Ардчилсан нам  Enkhmurun Erdenebat     1000001
#
#   reach_upper  spend_lower  spend_upper  ad_days
# 0         NaN          2.0           99      2.0
# 1         NaN          2.0           99      2.0

# %%
df.groupby(by=['Page Name']).sum().sort_values('spend_upper', ascending=False)[:10]
# Out:
#                                          spend_lower  spend_upper  ad_days
# Page Name
# Humane Society International                 50000.0        57491     24.0
# EveryJew                                     10710.0        13089     23.0
# РЫБАКОВ ФОНД                                  8000.0         8999      2.0
# Speechify                                     6002.0         7098      2.0
# Asian Development Bank Institute - ADBI       1600.0         2198     11.0
# Баярсайхан Галигаа Bayarsaikhan Galigaa       1301.0         1894     21.0
# Braindom 2: Riddle Game                       1000.0         1499      0.0
# ProstaGenix.com                               1000.0         1499      7.0
# Кулинарная школа ЩиБорщи                      1000.0         1499      2.0
# UNRWA                                         1200.0         1398      3.0

# %% [markdown]
# ## Top Payers

# %%
df.groupby(by=['Disclaimer']).sum().sort_values('spend_upper', ascending=False)[:10]
# Out:
#                                     spend_lower  spend_upper  ad_days
# Disclaimer
# These ads ran without a disclaimer      85157.0       109368    318.0
# Баярсайхан Галигаа                       1301.0         1894     21.0
# Khassuuri Gankhuyag                        42.0         1188     42.0
# Enkhmurun Erdenebat                       309.0         1092     19.0
# Batsaikhan Bat                             44.0         1089     44.0
# Nurbyek Samalkhan                          31.0          990     31.0
# Энхчулуун Чинбат                           15.0          990     15.0
# Baska Mn                                   41.0          891     41.0
# Уянгаа Алтангэрэл                          24.0          891     24.0
# Gantulga Lkhaakhuu                         16.0          891     16.0

# %%
df['page_id'] = df['page_id'].astype('int')

# %%
df.groupby(by=['Disclaimer','Page Name']).mean()
# Out:
#                                                                                             page_id  \
# Disclaimer                         Page Name
# Anar Munkhsaikhan                  Ламжавын Гүндалай                                   3.032196e+14
# Anudari Ayush                      Women for Change NGO / Өөрчлөлтийн төлөөх Эмэгт...  1.550179e+14
# Baagii Bat-Erdene                  Монгол Улсын Сонгуулийн ерөнхий хороо               1.085788e+14
# Baasanjargal Baska                 Нэхүүл Нам Бус Залуусын Хөдөлгөөн                   2.850413e+14
# Baasanjav Damdinsuren              Бямбасүрэнгийн Мягмар                               5.607064e+14
# Baska Mn                           Todmedee.mn                                         4.579059e+14
#                                    Б.Жаргалсайхан                                      7.429019e+14
#                                    Дуулиа бичлэгүүд                                    1.005837e+14
#                                    Мэдээ мэдээлэл Төв                                  7.214332e+14
#                                    Сенса мэдээ                                         1.074604e+14
#                                    Сошиал Мэдээ                                        4.023803e+14
# Batsaikhan Bat                     Niitlel.mn нийтлэл.мн                               1.004319e+14
#                                    SNEWS                                               5.808821e+14
#                                    Сонин мэдээ                                         1.604427e+14
# Batzaya Otgon                      Vip76                                               5.172839e+14
# Chantsaldulam Munkhtumur           Ардчилсан хувьсгалын ахмад зүтгэлтний хороо         1.942350e+15
# Delgerekh Khishi                   Өлзий-Оршихын Сумъяабаатар                          6.722139e+14
# Dulguun Enkhtsogt                  LEAD Alumni Association                             2.065952e+15
# Enhbadrah Bathuyag                 УИХ-ын гишүүн С.Батболдын Ажлын Алба                3.458816e+14
# Enkh-Amgalan Byambasuren           Бямбасүрэнгийн Энх-Амгалан Enkh-Amgalan Byambas...  1.086766e+15
# Enkhkhudulmur Tsogerdene           Ардчилсан нам                                       2.101752e+14
# Enkhmurun Erdenebat                Democratic Party Ардчилсан нам                      1.001795e+14
# Enkhtungalag Nyamdorj              Болдын Жавхлан Javkhlan Bold                        1.204136e+15
# Ganbaatar Jambal                   Жамбалын Ганбаатар                                  1.715214e+14
# Gantulga Donorov                   Доноровын Гантулга - Gantulga Donorov               7.173680e+14
# Gantulga Lkhaakhuu                 Судлаач Ганаа                                       1.583373e+14
# Hunnu Shoes Mongolian Brand        Hunnu Shoes Mongolian Brand                         1.750758e+15
# Jargalsaikhan Derem                Дархан-Уул аймаг дахь Ардчилсан нам                 1.015596e+14
# Khassuuri Gankhuyag                Хассуурийн Ганхуяг                                  8.445798e+14
# Lamjav Zolbaatar                   Barometer                                           2.555424e+14
# MUNKHBAATAR Lkhagva                MUNKHBAATAR Lkhagva                                 2.847325e+14
# Munkhchimeg Moonon                 Н.Алтаншагай                                        6.927627e+14
# Munkhtur Ravjir                    Тогмидын Доржханд                                   1.486822e+15
#                                    Хөдөлмөрийн Үндэсний Нам - ХҮН                      1.715979e+15
# Naranbaatar Nanzad                 Нанзадын Наранбаатар                                8.461313e+14
# Batsaikhan Bat                     Niitlel.mn нийтлэл.мн                                  5.000000
#                                    SNEWS                                                  3.500000
#                                    Сонин мэдээ                                            5.000000
# Batzaya Otgon                      Vip76                                                  1.714286
# Chantsaldulam Munkhtumur           Ардчилсан хувьсгалын ахмад зүтгэлтний хороо            0.000000
# Delgerekh Khishi                   Өлзий-Оршихын Сумъяабаатар                             1.250000
# Dulguun Enkhtsogt                  LEAD Alumni Association                                4.000000
# Enhbadrah Bathuyag                 УИХ-ын гишүүн С.Батболдын Ажлын Алба                 100.000000
# Enkh-Amgalan Byambasuren           Бямбасүрэнгийн Энх-Амгалан Enkh-Amgalan Byambas...     2.333333
# Enkhkhudulmur Tsogerdene           Ардчилсан нам                                         34.333333
# Enkhmurun Erdenebat                Democratic Party Ардчилсан нам                        38.625000
# Enkhtungalag Nyamdorj              Болдын Жавхлан Javkhlan Bold                           5.000000
# Ganbaatar Jambal                   Жамбалын Ганбаатар                                     3.500000
# Gantulga Donorov                   Доноровын Гантулга - Gantulga Donorov                  4.000000
# Gantulga Lkhaakhuu                 Судлаач Ганаа                                          1.777778
# Hunnu Shoes Mongolian Brand        Hunnu Shoes Mongolian Brand                            5.000000
# Jargalsaikhan Derem                Дархан-Уул аймаг дахь Ардчилсан нам                    3.000000
# Khassuuri Gankhuyag                Хассуурийн Ганхуяг                                     3.500000
# Lamjav Zolbaatar                   Barometer                                              1.500000
# MUNKHBAATAR Lkhagva                MUNKHBAATAR Lkhagva                                    4.333333
# Munkhchimeg Moonon                 Н.Алтаншагай                                           2.000000
# Munkhtur Ravjir                    Тогмидын Доржханд                                      3.000000
#                                    Хөдөлмөрийн Үндэсний Нам - ХҮН                         3.333333
# Naranbaatar Nanzad                 Нанзадын Наранбаатар                                   3.500000
# Nurbyek Samalkhan                  Ганибалын Амартүвшин                                   3.100000
# Ochirpurev Nyamjav                 Бямбацогт Сандаг                                     200.000000
# Purevdorj Bukhchuluun              Purevdorj Bukhchuluun                                  3.000000
# Sod-Od Batzorig                    Амгалангийн Адъяасүрэн                               100.000000
# Sodmagnai Enkhjargal               Монгол ардын нам                                      50.500000
# These ads ran without a disclaimer 2020 оны сонгууль                                      2.000000
#                                    AIT Department of Energy, Environment and Clima...   100.000000
#                                    Amir Tsarfati                                          1.000000
#                                    Angus and Rohini Ross: The Rewilders                   1.000000
#                                    Anomali                                              100.000000
#                                    Asian Development Bank Institute - ADBI              800.000000
#                                    Banque mondiale                                        1.600000
#                                    Barilga.mn                                             4.000000
#                                    Be the change with Sophia                              1.000000
#                                    Beste Investeringen1                                   3.000000
#                                    Braindom 2: Riddle Game                             1000.000000
#                                    Bravo novel                                          100.000000
#                                    CarFast                                                2.000000
#                                    China Xinhua Sci-Tech                                  2.000000
#                                    Claims Conference (Conference on Jewish Materia...   300.000000
#                                    D+C Development and Cooperation                        0.000000
#                                    Deutschland.de                                         3.000000
#                                    Dian Nugraha                                           2.000000
#                                    EU International Partnerships                          1.000000
#                                    EveryJew                                             973.636364
#                                    Global Heroes                                          1.000000
# Лүндэгийн Наранбаатар              Лүндэгийн Наранбаатар Naranbaatar Lundeg              50.500000
# Уянгаа Алтангэрэл                  Монгол Ардын Намын Бүлэг                               2.666667
# Цогзолбаяр Бямбадалай              М.Оюунчимэг гишүүнийг дэмжигчдийн хуудас               2.000000
#                                    УИХ-ын Нийгмийн Бодлогын Байнгын Хороо                 1.750000
# Энхчулуун Чинбат                   Дамбын Батлут                                          1.500000
#
#                                                                                        spend_upper  \
# Disclaimer                         Page Name
# Anar Munkhsaikhan                  Ламжавын Гүндалай                                    119.000000
# Anudari Ayush                      Women for Change NGO / Өөрчлөлтийн төлөөх Эмэгт...    99.000000
# Baagii Bat-Erdene                  Монгол Улсын Сонгуулийн ерөнхий хороо                 99.000000
# Baasanjargal Baska                 Нэхүүл Нам Бус Залуусын Хөдөлгөөн                     99.000000
# Baasanjav Damdinsuren              Бямбасүрэнгийн Мягмар                                 99.000000
# Baska Mn                           Todmedee.mn                                           99.000000
#                                    Б.Жаргалсайхан                                        99.000000
#                                    Дуулиа бичлэгүүд                                      99.000000
#                                    Мэдээ мэдээлэл Төв                                    99.000000
#                                    Сенса мэдээ                                           99.000000
#                                    Сошиал Мэдээ                                          99.000000
# Batsaikhan Bat                     Niitlel.mn нийтлэл.мн                                 99.000000
#                                    SNEWS                                                 99.000000
#                                    Сонин мэдээ                                           99.000000
# Batzaya Otgon                      Vip76                                                 99.000000
# Chantsaldulam Munkhtumur           Ардчилсан хувьсгалын ахмад зүтгэлтний хороо           99.000000
# Delgerekh Khishi                   Өлзий-Оршихын Сумъяабаатар                            99.000000
# Dulguun Enkhtsogt                  LEAD Alumni Association                               99.000000
# Enhbadrah Bathuyag                 УИХ-ын гишүүн С.Батболдын Ажлын Алба                 199.000000
# Enkh-Amgalan Byambasuren           Бямбасүрэнгийн Энх-Амгалан Enkh-Amgalan Byambas...    99.000000
# Enkhkhudulmur Tsogerdene           Ардчилсан нам                                        132.333333
# Enkhmurun Erdenebat                Democratic Party Ардчилсан нам                       136.500000
# Enkhtungalag Nyamdorj              Болдын Жавхлан Javkhlan Bold                          99.000000
# Ganbaatar Jambal                   Жамбалын Ганбаатар                                    99.000000
# Gantulga Donorov                   Доноровын Гантулга - Gantulga Donorov                 99.000000
# Gantulga Lkhaakhuu                 Судлаач Ганаа                                         99.000000
# Hunnu Shoes Mongolian Brand        Hunnu Shoes Mongolian Brand                           99.000000
# Jargalsaikhan Derem                Дархан-Уул аймаг дахь Ардчилсан нам                   99.000000
# Khassuuri Gankhuyag                Хассуурийн Ганхуяг                                    99.000000
# Lamjav Zolbaatar                   Barometer                                             99.000000
# MUNKHBAATAR Lkhagva                MUNKHBAATAR Lkhagva                                   99.000000
# Munkhchimeg Moonon                 Н.Алтаншагай                                          99.000000
# Munkhtur Ravjir                    Тогмидын Доржханд                                     99.000000
#                                    Хөдөлмөрийн Үндэсний Нам - ХҮН                        99.000000
# Naranbaatar Nanzad                 Нанзадын Наранбаатар                                  99.000000
#                                    Бүтэнбаяр Сүндэръяа                                   99.000000
#                                    Кулинарная школа ЩиБорщи                            1499.000000
#                                    Монгол ХҮҮ                                            99.000000
#                                    Мөнгөгүй улс төр АН-ын шударга гишүүдийн хөдөлгөөн    99.000000
#                                    Нийгмийн Ардчилал Монголын Залуучуудын Холбоо        199.000000
#                                    Ноцтой мэдээ                                          99.000000
#                                    РЫБАКОВ ФОНД                                        8999.000000
#                                    Сошиализм & Socializm                                 99.000000
#                                    Хүүкийг дэмжигчид                                     99.000000
#                                    Экскурсии по Европе Прага Чехия                      119.000000
#                                    מכללת יוזמות-אנשים יוזמים הצלחות                      99.000000
#                                    العين فارسى AlAin Persian                             99.000000
#                                    今日海峽                                                 249.000000
#                                    守护者                                                   99.000000
#                                    株式会社Medifellow                                       199.000000
# Tsedendamba Enkhtur                Жигжидсүрэнгийн Чинбүрэн                              99.000000
# Tugsbayar Batsaikhan               Yazguur.mn                                            99.000000
#                                    Энхтайваны Бат-Амгалан                                99.000000
# Tuvshin Jargal                     Future of Mongolia                                    99.000000
# Батбаяр Дамиран                    Гонгорын Дамдинням                                    99.000000
# Баярсайхан Галигаа                 Баярсайхан Галигаа Bayarsaikhan Galigaa              315.666667
# Лүндэгийн Наранбаатар              Лүндэгийн Наранбаатар Naranbaatar Lundeg             149.000000
# Уянгаа Алтангэрэл                  Монгол Ардын Намын Бүлэг                              99.000000
# Цогзолбаяр Бямбадалай              М.Оюунчимэг гишүүнийг дэмжигчдийн хуудас              99.000000
#                                    УИХ-ын Нийгмийн Бодлогын Байнгын Хороо                99.000000
# Энхчулуун Чинбат                   Дамбын Батлут                                         99.000000
#
#                                                                                          ad_days
# Disclaimer                         Page Name
# Anar Munkhsaikhan                  Ламжавын Гүндалай                                    3.600000
# Anudari Ayush                      Women for Change NGO / Өөрчлөлтийн төлөөх Эмэгт...   2.000000
# Baagii Bat-Erdene                  Монгол Улсын Сонгуулийн ерөнхий хороо                4.333333
# Baasanjargal Baska                 Нэхүүл Нам Бус Залуусын Хөдөлгөөн                    1.333333
# Baasanjav Damdinsuren              Бямбасүрэнгийн Мягмар                                4.333333
# Baska Mn                           Todmedee.mn                                          4.500000
#                                    Б.Жаргалсайхан                                       3.666667
#                                    Дуулиа бичлэгүүд                                     5.000000
#                                    Мэдээ мэдээлэл Төв                                   5.000000
#                                    Сенса мэдээ                                          6.000000
#                                    Сошиал Мэдээ                                         5.000000
# Batsaikhan Bat                     Niitlel.mn нийтлэл.мн                                5.000000
#                                    SNEWS                                                3.500000
#                                    Сонин мэдээ                                          5.000000
# Batzaya Otgon                      Vip76                                                1.714286
# Chantsaldulam Munkhtumur           Ардчилсан хувьсгалын ахмад зүтгэлтний хороо          0.000000
# Delgerekh Khishi                   Өлзий-Оршихын Сумъяабаатар                           1.250000
# Dulguun Enkhtsogt                  LEAD Alumni Association                              4.000000
# Enhbadrah Bathuyag                 УИХ-ын гишүүн С.Батболдын Ажлын Алба                 4.000000
# Enkh-Amgalan Byambasuren           Бямбасүрэнгийн Энх-Амгалан Enkh-Amgalan Byambas...   2.333333
# Enkhkhudulmur Tsogerdene           Ардчилсан нам                                        2.000000
# Enkhmurun Erdenebat                Democratic Party Ардчилсан нам                       2.375000
# Enkhtungalag Nyamdorj              Болдын Жавхлан Javkhlan Bold                         5.000000
# Ganbaatar Jambal                   Жамбалын Ганбаатар                                   3.500000
# Gantulga Donorov                   Доноровын Гантулга - Gantulga Donorov                4.000000
# Gantulga Lkhaakhuu                 Судлаач Ганаа                                        1.777778
# Hunnu Shoes Mongolian Brand        Hunnu Shoes Mongolian Brand                          5.000000
# Jargalsaikhan Derem                Дархан-Уул аймаг дахь Ардчилсан нам                  3.000000
# Khassuuri Gankhuyag                Хассуурийн Ганхуяг                                   3.500000
# Lamjav Zolbaatar                   Barometer                                            1.500000
# MUNKHBAATAR Lkhagva                MUNKHBAATAR Lkhagva                                  4.333333
# Munkhchimeg Moonon                 Н.Алтаншагай                                         2.000000
# Munkhtur Ravjir                    Тогмидын Доржханд                                    3.000000
#                                    Хөдөлмөрийн Үндэсний Нам - ХҮН                       3.333333
# Naranbaatar Nanzad                 Нанзадын Наранбаатар                                 3.500000
# Nurbyek Samalkhan                  Ганибалын Амартүвшин                                 3.100000
# Ochirpurev Nyamjav                 Бямбацогт Сандаг                                     5.500000
# Purevdorj Bukhchuluun              Purevdorj Bukhchuluun                                3.000000
# Sod-Od Batzorig                    Амгалангийн Адъяасүрэн                               2.000000
# Sodmagnai Enkhjargal               Монгол ардын нам                                     2.000000
# These ads ran without a disclaimer 2020 оны сонгууль                                    2.000000
#                                    AIT Department of Energy, Environment and Clima...   2.000000
#                                    Amir Tsarfati                                        1.000000
#                                    Angus and Rohini Ross: The Rewilders                 1.000000
#                                    Anomali                                              7.000000
#                                    Asian Development Bank Institute - ADBI              5.500000
#                                    Banque mondiale                                      1.600000
#                                    Barilga.mn                                           4.000000
#                                    Be the change with Sophia                            1.000000
#                                    Beste Investeringen1                                 3.000000
#                                    Braindom 2: Riddle Game                                   NaN
#                                    Bravo novel                                          1.000000
#                                    CarFast                                              2.000000
#                                    China Xinhua Sci-Tech                                2.000000
#                                    Claims Conference (Conference on Jewish Materia...   6.000000
#                                    D+C Development and Cooperation                      0.000000
#                                    Deutschland.de                                       3.000000
#                                    Dian Nugraha                                         2.000000
#                                    EU International Partnerships                        1.000000
#                                    EveryJew                                             2.090909
#                                    Global Heroes                                        1.000000
#                                    Humane Society International                         2.666667
#                                    IFC - International Finance Corporation              2.000000
#                                    Ideagen                                              1.000000
#                                    Indigenous Peoples Rights International              2.000000
#                                    Insight Ningbo                                       1.000000
#                                    Inspiring 慈悲世界                                       6.000000
#                                    Israel Alliance                                     19.000000
#                                    Language Translator-Easy&Fast                        8.000000
#                                    Longyuan SA Renewables                               1.000000
#                                    MDPI                                                 2.000000
#                                    MN WORLD                                             1.000000
#                                    Marohe                                               2.000000
#                                    Me-Read                                              2.000000
#                                    Meilleur Film HD                                     2.000000
#                                    Mixmag                                               1.500000
#                                    Money Pop                                            1.000000
#                                    National Library of Israel                           2.000000
#                                    National Park Rescue Campaigns                       1.000000
#                                    Ockenden International Prizes                        0.000000
#                                    Opportunities in Canada                              1.000000
#                                    PIERO BT                                            12.000000
#                                    PMI Mongolia Chapter                                 6.000000
#                                    ProstaGenix.com                                      7.000000
#                                    RioOnWatch.org                                       1.000000
#                                    RoboForex                                            0.000000
#                                    SL Elevator Co.,Ltd.                                 2.000000
#                                    Seoul Garden цогцолбор                               1.000000
#                                    Speechify                                            2.000000
#                                    Synergy Marine Group                                 1.000000
#                                    TVBee World                                          7.000000
#                                    Tatar.mn news                                        1.000000
#                                    Techshop                                             1.000000
#                                    The Economist Intelligence Unit                     10.000000
#                                    The Fraser Institute                                 8.000000
#                                    Tovch.mn                                             5.000000
#                                    Trend news                                           1.333333
#                                    UNRWA                                                1.500000
#                                    United States Institute of Peace                     1.000000
#                                    Wild For Change                                      1.000000
#                                    World Cleanup Day                                    1.000000
#                                    Xin                                                  2.000000
#                                    Zhangjiagang, China                                  1.000000
#                                    chinadialogue                                        2.500000
#                                    tcahmetreyizyilmaz                                   2.000000
#                                    Énergie Paisible                                     0.400000
#                                    Б.Отгон                                              6.000000
#                                    Бүтэнбаяр Сүндэръяа                                  3.000000
#                                    Кулинарная школа ЩиБорщи                             2.000000
#                                    Монгол ХҮҮ                                           0.000000
#                                    Мөнгөгүй улс төр АН-ын шударга гишүүдийн хөдөлгөөн   1.000000
#                                    Нийгмийн Ардчилал Монголын Залуучуудын Холбоо        3.000000
#                                    Ноцтой мэдээ                                         1.000000
#                                    РЫБАКОВ ФОНД                                         2.000000
#                                    Сошиализм & Socializm                                1.500000
#                                    Хүүкийг дэмжигчид                                    1.500000
#                                    Экскурсии по Европе Прага Чехия                      1.600000
#                                    מכללת יוזמות-אנשים יוזמים הצלחות                     1.000000
#                                    العين فارسى AlAin Persian                            1.000000
#                                    今日海峽                                                 3.500000
#                                    守护者                                                  1.000000
#                                    株式会社Medifellow                                       2.000000
# Tsedendamba Enkhtur                Жигжидсүрэнгийн Чинбүрэн                             2.000000
# Tugsbayar Batsaikhan               Yazguur.mn                                           3.000000
#                                    Энхтайваны Бат-Амгалан                               7.000000
# Tuvshin Jargal                     Future of Mongolia                                   5.000000
# Батбаяр Дамиран                    Гонгорын Дамдинням                                   3.000000
# Баярсайхан Галигаа                 Баярсайхан Галигаа Bayarsaikhan Galigaa              3.500000
# Лүндэгийн Наранбаатар              Лүндэгийн Наранбаатар Naranbaatar Lundeg             1.500000
# Уянгаа Алтангэрэл                  Монгол Ардын Намын Бүлэг                             2.666667
# Цогзолбаяр Бямбадалай              М.Оюунчимэг гишүүнийг дэмжигчдийн хуудас             2.000000
#                                    УИХ-ын Нийгмийн Бодлогын Байнгын Хороо               1.750000
# Энхчулуун Чинбат                   Дамбын Батлут                                        1.500000

# %% [markdown]
# If we need to convert a list inside a series to a dataframe we can do this. We will use this later.

# %%
pd.DataFrame(ast.literal_eval(df['demographic_distribution'][0]))
